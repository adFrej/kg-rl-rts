# %%
from score import Scorer

# %% [markdown]
# # Basic score

# %%
s = Scorer().add_score(r"MicroRTSGridModeVecEnv__ppo_gridnet____7__1723935982", "basic")\
    .draw_avg("Basic score over 100M steps", x_line=5e7)

# %%
basic_50 = [
    r"MicroRTSGridModeVecEnv__ppo_gridnet____8__1724231973",
    r"MicroRTSGridModeVecEnv__ppo_gridnet____9__1724275145",
    r"MicroRTSGridModeVecEnv__ppo_gridnet____10__1724368618",
    r"MicroRTSGridModeVecEnv__ppo_gridnet____11__1725054040",
    r"MicroRTSGridModeVecEnv__ppo_gridnet____12__1727131731",
]

# %%
s = Scorer().add_many_scores(basic_50, "basic").draw_avg("Basic score over 50M steps")

# %% [markdown]
# # KG6

# %%
s = Scorer().add_many_scores(basic_50, "basic").add_score(r"MicroRTSGridModeVecEnv__ppo_gridnet__prior__kg6__26__1725546267", "kg", directory="kg6").draw_avg("Comparison with 6 walk depth")

# %%
s = Scorer().add_many_scores(basic_50, "basic").add_many_scores([
    r"MicroRTSGridModeVecEnv__ppo_gridnet__prior__kg6__27__1725600878",
    r"MicroRTSGridModeVecEnv__ppo_gridnet__prior__kg6__28__1725665586",
    r"MicroRTSGridModeVecEnv__ppo_gridnet__prior__kg6__29__1725716693",
], "kg", directory="kg6").draw_avg("Comparison with 5 walk depth")

# %%
s = Scorer().add_many_scores(basic_50, "basic").add_many_scores([
    r"MicroRTSGridModeVecEnv__ppo_gridnet__prior__kg6__30__1725767007",
    r"MicroRTSGridModeVecEnv__ppo_gridnet__prior__kg6__32__1725924020",
], "kg", directory="kg6").draw_avg("Comparison with 3 walk depth")

# %%
s = Scorer().add_many_scores(basic_50, "basic").add_many_scores([
    r"MicroRTSGridModeVecEnv__ppo_gridnet__prior__kg6__31__1725826091",
], "kg", directory="kg6").draw_avg("Comparison with 3 walk depth, 128 vector length")

# %%
s = Scorer().add_many_scores(basic_50, "basic").add_many_scores([
    r"MicroRTSGridModeVecEnv__ppo_gridnet__prior__kg6__33__1726129791",
    r"MicroRTSGridModeVecEnv__ppo_gridnet__prior__kg6__34__1726185003",
    r"MicroRTSGridModeVecEnv__ppo_gridnet__prior__kg6__35__1726265580",
    r"MicroRTSGridModeVecEnv__ppo_gridnet__prior__kg6__36__1726608426",
    r"MicroRTSGridModeVecEnv__ppo_gridnet__prior__kg6__37__1726694297",
    r"MicroRTSGridModeVecEnv__ppo_gridnet__prior__kg6__38__1726780963",
], "kg", directory="kg6").draw_avg("Comparison with 3 walk depth, 16 vector length")

# %% [markdown]
# # KG7

# %%
s = Scorer().add_many_scores(basic_50, "basic").add_many_scores([
    r"MicroRTSGridModeVecEnv__ppo_gridnet__prior__kg7__39__1728514745",
], "kg", directory="kg7").draw_avg("Comparison with 3 walk depth, 16 vector length and advices", step_limit=7.1e6)

# %%
s = Scorer().add_many_scores(basic_50, "basic").add_many_scores([
    r"MicroRTSGridModeVecEnv__ppo_gridnet__prior__kg7__40__1728593782",
], "kg", directory="kg7").draw_avg("Comparison with 3 walk depth, 16 vector length and advices")

# %%
s = Scorer().add_many_scores(basic_50, "basic").add_many_scores([
    r"MicroRTSGridModeVecEnv__ppo_gridnet__prior__kg7__41__1728778945",
], "kg", directory="kg7").draw_avg("Comparison with 3 walk depth, 16 vector length and advices", step_limit=1.95e7)

# %%
s = Scorer().add_many_scores(basic_50, "basic").add_many_scores([
    r"MicroRTSGridModeVecEnv__ppo_gridnet__prior__kg7__41__1728826768",
    r"MicroRTSGridModeVecEnv__ppo_gridnet__prior__kg7__42__1728865193",
], "kg", directory="kg7").draw_avg("Comparison with vector advices", step_limit=1.55e7)

# %%
s = Scorer().add_many_scores(basic_50, "basic").add_many_scores([
    r"MicroRTSGridModeVecEnv__ppo_gridnet__prior__kg7__43__1728920812",
    r"MicroRTSGridModeVecEnv__ppo_gridnet__prior__kg7__44__1728978142",
    r"MicroRTSGridModeVecEnv__ppo_gridnet__prior__kg7__45__1729029252",
], "kg", directory="kg7").draw_avg("Comparison with vector advices", step_limit=1.55e7)

# %%
s = Scorer().add_many_scores(basic_50, "basic").add_many_scores([
    r"MicroRTSGridModeVecEnv__ppo_gridnet__prior__kg7__45__1729029252",
], "kg", directory="kg7").draw_avg("Comparison with vector advices", step_limit=2.1e7)

# %%
s = Scorer().add_many_scores(basic_50, "basic").add_many_scores([
    r"MicroRTSGridModeVecEnv__ppo_gridnet__prior__kg7__46__1729126385",
], "kg", directory="kg7").draw_avg("Comparison with vector advices", step_limit=2.1e7)

# %% [markdown]
# ## Bugged ratings!:

# %%
s = Scorer().add_many_scores(basic_50, "basic").add_many_scores([
    r"MicroRTSGridModeVecEnv__ppo_gridnet__prior__kg7__47__1729292373",
], "kg", directory="kg7").draw_avg("Comparison with one hot encoded vector advices", step_limit=1.55e7)

# %%
basic_3 = [
    r"MicroRTSGridModeVecEnv__ppo_gridnet____13__1729470809",
    r"MicroRTSGridModeVecEnv__ppo_gridnet____14__1729554172",
]

# %%
s = Scorer().add_many_scores(basic_3, "basic").add_many_scores([
    r"MicroRTSGridModeVecEnv__ppo_gridnet__prior__kg7__48__1729381462",
    r"MicroRTSGridModeVecEnv__ppo_gridnet__prior__kg7__49__1729421235",
], "kg", directory="kg7").draw_avg("Comparison with one hot encoded vector advices")

# %%
basic_1 = [
    r"MicroRTSGridModeVecEnv__ppo_gridnet____15__1729683980",
    r"MicroRTSGridModeVecEnv__ppo_gridnet____16__1729767276",
]

# %%
s = Scorer().add_many_scores(basic_1, "basic").add_many_scores([
    r"MicroRTSGridModeVecEnv__ppo_gridnet__prior__kg7__50__1729636476",
    r"MicroRTSGridModeVecEnv__ppo_gridnet__prior__kg7__51__1729723837",
], "kg", directory="kg7").draw_avg("Comparison with one hot encoded vector advices")

# %%
s = Scorer().add_many_scores(basic_3 + basic_1, "basic").add_many_scores([
    r"MicroRTSGridModeVecEnv__ppo_gridnet__prior__kg7__48__1729381462",
    r"MicroRTSGridModeVecEnv__ppo_gridnet__prior__kg7__49__1729421235",
    r"MicroRTSGridModeVecEnv__ppo_gridnet__prior__kg7__50__1729636476",
    r"MicroRTSGridModeVecEnv__ppo_gridnet__prior__kg7__51__1729723837",
], "kg", directory="kg7").draw_avg("Comparison with one hot encoded vector advices", step_limit=1e6)

# %% [markdown]
# ## Fixed ratings:

# %%
s = Scorer().add_many_scores(basic_3, "basic").add_many_scores([
    r"MicroRTSGridModeVecEnv__ppo_gridnet__prior__kg7__52__1729811260",
], "kg", directory="kg7").draw_avg("Comparison with one hot encoded vector advices")

# %% [markdown]
# # KG8

# %%
s = Scorer().add_many_scores(basic_3, "basic").add_many_scores([
    r"MicroRTSGridModeVecEnv__ppo_gridnet__prior__kg8__53__1730162100",
], "kg", directory="kg8").draw_avg("Comparison with one hot encoded vector advices")

# %% [markdown]
# ## No reward, not even win loss:

# %%
s = Scorer().add_many_scores(basic_1, "basic").add_many_scores([
    r"MicroRTSGridModeVecEnv__ppo_gridnet____17__1730295373",
], "basic_no_reward", directory="base_no_reward").draw_avg("Comparison with no reward")

# %%
basic_1_no_reward = [
    r"MicroRTSGridModeVecEnv__ppo_gridnet____17__1730295373",
]

# %%
s = Scorer().add_many_scores(basic_1_no_reward, "basic", directory="base_no_reward").add_many_scores([
    r"MicroRTSGridModeVecEnv__ppo_gridnet__prior__kg8__54__1730375064",
], "kg", directory="kg8").draw_avg("Comparison no reward with one hot encoded vector advices")

# %%
s = Scorer().add_many_scores(basic_1_no_reward, "basic", directory="base_no_reward").add_many_scores([
    r"MicroRTSGridModeVecEnv__ppo_gridnet__prior__kg8__55__1730392694",
], "kg", directory="kg8").draw_avg("Comparison no reward with advice reward")

# %%
s = Scorer().add_many_scores(basic_50, "basic", directory="base").add_many_scores([
    r"MicroRTSGridModeVecEnv__ppo_gridnet__prior__kg8__56__1730404537",
], "kg", directory="kg8").draw_avg("Comparison reward with advice reward", step_limit=1e7)

# %% [markdown]
# ## Fixed no reward:

# %%
s = Scorer().add_many_scores(basic_50, "basic").add_many_scores([
    r"MicroRTSGridModeVecEnv__ppo_gridnet____18__1730477140",
], "basic no reward shaping", directory="base_no_reward").draw_avg("Comparison with no reward", step_limit=1e7)

# %%
basic_10_no_reward = [
    r"MicroRTSGridModeVecEnv__ppo_gridnet____18__1730477140",
]

# %%
# 0.1 weight
s = Scorer().add_many_scores(basic_10_no_reward, "basic", directory="base_no_reward").add_many_scores([
    r"MicroRTSGridModeVecEnv__ppo_gridnet__prior__kg8__57__1730534934",
], "kg", directory="kg8").draw_avg("Comparison no reward with advice reward")

# %%
# 0.005 weight
s = Scorer().add_many_scores(basic_10_no_reward, "basic", directory="base_no_reward").add_many_scores([
    r"MicroRTSGridModeVecEnv__ppo_gridnet__prior__kg8__58__1730570358",
], "kg", directory="kg8").draw_avg("Comparison no reward with advice reward")

# %% [markdown]
# Averaged rewards through actions:

# %%
# 0.05 weight
s = Scorer().add_many_scores(basic_10_no_reward, "basic", directory="base_no_reward").add_many_scores([
    r"MicroRTSGridModeVecEnv__ppo_gridnet__prior__kg8__59__1730651598",
], "kg", directory="kg8").draw_avg("Comparison no reward with advice reward")

# %%
# 0.05 weight
s = Scorer()\
    .add_many_scores(basic_10_no_reward, "basic", directory="base_no_reward")\
    .add_many_scores([
    r"MicroRTSGridModeVecEnv__ppo_gridnet__prior__kg8__59__1730651598",
], "kg", directory="kg8")\
    .add_many_scores(basic_50, "basic reward shaping")\
    .draw_avg("Comparison no reward with advice reward", step_limit=1e7)

# %%
# 0.01 weight
s = Scorer().add_many_scores(basic_10_no_reward, "basic", directory="base_no_reward").add_many_scores([
    r"MicroRTSGridModeVecEnv__ppo_gridnet__prior__kg8__60__1730731493",
], "kg", directory="kg8").draw_avg("Comparison no reward with advice reward", step_limit=0.6e7)

# %% [markdown]
# ## Removed self play:

# %%
basic_10 = [
    r"MicroRTSGridModeVecEnv__ppo_gridnet____20__1731031374",
    r"MicroRTSGridModeVecEnv__ppo_gridnet____21__1731120048",
]

# %%
basic_10_no_reward = [
    r"MicroRTSGridModeVecEnv__ppo_gridnet____19__1730991764",
]

# %%
# 0.05 weight
s = Scorer().add_many_scores(basic_10_no_reward, "basic", directory="base_no_reward").add_many_scores([
    r"MicroRTSGridModeVecEnv__ppo_gridnet__prior__kg8__61__1730757655",
], "kg", directory="kg8").draw_avg("Comparison no reward with advice reward")

# %%
# more base targeting
# 0.05 weight
s = Scorer().add_many_scores(basic_10_no_reward, "basic", directory="base_no_reward").add_many_scores([
    r"MicroRTSGridModeVecEnv__ppo_gridnet__prior__kg8__62__1730821700",
], "kg", directory="kg8").draw_avg("Comparison no reward with advice reward", step_limit=0.4e7)

# %% [markdown]
# # KG9

# %%
# 0.05 weight
s = Scorer().add_many_scores(basic_10_no_reward, "basic", directory="base_no_reward").add_many_scores([
    r"MicroRTSGridModeVecEnv__ppo_gridnet__prior__kg9__63__1730859872",
], "kg", directory="kg9").draw_avg("Comparison no reward with advice reward", step_limit=0.55e7)

# %% [markdown]
# ## Changed expert to kg reward shaping:

# %%
# 0.1 weight
s = Scorer()\
    .add_many_scores(basic_10_no_reward, "basic", directory="base_no_reward")\
    .add_many_scores([
    r"MicroRTSGridModeVecEnv__ppo_gridnet__prior__kg9__64__1730911026",
], "kg", directory="kg9")\
    .add_many_scores(basic_10, "basic reward shaping")\
    .draw_avg("Comparison no reward with advice reward")

# %% [markdown]
# # KG10

# %%
# 0.1 weight
s = Scorer()\
    .add_many_scores(basic_10_no_reward, "basic", directory="base_no_reward")\
    .add_many_scores([
    r"MicroRTSGridModeVecEnv__ppo_gridnet__prior__kg10__65__1731202122",
    r"MicroRTSGridModeVecEnv__ppo_gridnet__prior__kg10__66__1731244153",
    r"MicroRTSGridModeVecEnv__ppo_gridnet__prior__kg10__69__1731455694",
    r"MicroRTSGridModeVecEnv__ppo_gridnet__prior__kg10__70__1731493553",
    r"MicroRTSGridModeVecEnv__ppo_gridnet__prior__kg10__71__1731552669",
    r"MicroRTSGridModeVecEnv__ppo_gridnet__prior__kg10__72__1731628297",
], "kg", directory="kg10")\
    .add_many_scores(basic_10, "basic reward shaping")\
    .draw_avg("Comparison no reward with advice reward")

# %%
# 0.1 weight
s = Scorer()\
    .add_many_scores(basic_10_no_reward, "basic", directory="base_no_reward")\
    .add_many_scores([
    r"MicroRTSGridModeVecEnv__ppo_gridnet__prior__kg10__70__1731493553",
], "kg", directory="kg10")\
    .add_many_scores([
    r"MicroRTSGridModeVecEnv__ppo_gridnet__prior__kg10__70__1731702360",
], "kg distance", directory="kg10")\
    .add_many_scores(basic_10, "basic reward shaping")\
    .draw_avg("Comparison no reward with advice reward")

# %%
# 0.1 weight
s = Scorer()\
    .add_many_scores(basic_10_no_reward, "basic", directory="base_no_reward")\
    .add_many_scores([
    r"MicroRTSGridModeVecEnv__ppo_gridnet__prior__kg10__70__1731738474",
], "70", directory="kg11")\
    .add_many_scores([
    r"MicroRTSGridModeVecEnv__ppo_gridnet__prior__kg11__65__1731773149",
], "65", directory="kg11")\
    .add_many_scores(basic_10, "basic reward shaping")\
    .draw_avg("Comparison no reward with advice reward")

# %%
# 0.1 weight
s = Scorer()\
    .add_many_scores(basic_10_no_reward, "basic", directory="base_no_reward")\
    .add_many_scores([
    r"MicroRTSGridModeVecEnv__ppo_gridnet__prior__kg10__65__1731202122",
], "65 1", directory="kg10")\
    .add_many_scores([
    r"MicroRTSGridModeVecEnv__ppo_gridnet__prior__kg11__65__1731773149",
], "65 2", directory="kg11")\
    .add_many_scores([
    r"MicroRTSGridModeVecEnv__ppo_gridnet__prior__kg11__65__1731825557",
], "65 3", directory="kg11")\
    .add_many_scores(basic_10, "basic reward shaping")\
    .draw_avg("Comparison no reward with advice reward")

# %%
# 0.1 weight
s = Scorer()\
    .add_many_scores(basic_10_no_reward, "basic", directory="base_no_reward")\
    .add_many_scores([
    r"MicroRTSGridModeVecEnv__ppo_gridnet__prior__kg10__70__1731493553",
], "70 10", directory="kg10")\
    .add_many_scores([
    r"MicroRTSGridModeVecEnv__ppo_gridnet__prior__kg11__70__1731882010",
], "70 11", directory="kg11")\
    .add_many_scores(basic_10, "basic reward shaping")\
    .draw_avg("Comparison no reward with advice reward")

# %%
# 0.1 weight
s = Scorer()\
    .add_many_scores(basic_10_no_reward, "basic", directory="base_no_reward")\
#     .add_many_scores([
#     r"MicroRTSGridModeVecEnv__ppo_gridnet__prior__kg12__65__1731946198",
# ], "65", directory="kg12")\
#     .add_many_scores([
#     r"MicroRTSGridModeVecEnv__ppo_gridnet__prior__kg12__70__1731955759",
# ], "70 1", directory="kg12")\
    .add_many_scores([
    r"MicroRTSGridModeVecEnv__ppo_gridnet__prior__kg12__70__1731979667",
], "70 2", directory="kg12")\
    .add_many_scores([
    r"MicroRTSGridModeVecEnv__ppo_gridnet__prior__kg12__70__1732011202",
], "70 3", directory="kg12")\
    .add_many_scores([
    r"MicroRTSGridModeVecEnv__ppo_gridnet__prior__kg12__70__1732040107",
], "70 4", directory="kg12")\
    .add_many_scores(basic_10, "basic reward shaping")\
    .draw_avg("Comparison no reward with advice reward")

# %%
# 0.5 weight
s = Scorer()\
    .add_many_scores(basic_10_no_reward, "basic", directory="base_no_reward")\
    .add_many_scores([
    r"MicroRTSGridModeVecEnv__ppo_gridnet__prior__kg10__73__1731661698",
], "kg", directory="kg10")\
    .add_many_scores(basic_10, "basic reward shaping")\
    .draw_avg("Comparison no reward with advice reward")

# %%
# 0.05 weight
s = Scorer()\
    .add_many_scores(basic_10_no_reward, "basic", directory="base_no_reward")\
    .add_many_scores([
    r"MicroRTSGridModeVecEnv__ppo_gridnet__prior__kg10__74__1731681944",
], "kg", directory="kg10")\
    .add_many_scores(basic_10, "basic reward shaping")\
    .draw_avg("Comparison no reward with advice reward")

# %%
# 0.1 weight
s = Scorer()\
    .add_many_scores(basic_10_no_reward, "basic", directory="base_no_reward")\
    .add_many_scores([
    r"MicroRTSGridModeVecEnv__ppo_gridnet__prior__kg10__67__1731322459",
], "kg", directory="kg10")\
    .add_many_scores(basic_10, "basic reward shaping")\
    .draw_avg("Comparison no reward with reward expert")

# %%
# 0.1 weight
s = Scorer()\
    .add_many_scores(basic_10_no_reward, "basic", directory="base_no_reward")\
    .add_many_scores([
    r"MicroRTSGridModeVecEnv__ppo_gridnet__prior__kg10__68__1731411533",
], "kg", directory="kg10")\
    .add_many_scores(basic_10, "basic reward shaping")\
    .draw_avg("Comparison no reward with append vector")
